# %%
from astroquery.gaia import Gaia

# %%
#query_galaxy = "SELECT TOP 10000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.parallax, dr3.pm, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
#                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
#                p.classprob_dsc_allosmod_star AS star\
#        FROM gaiadr3.gaia_source as dr3\
#        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
#        WHERE dr3.parallax is not null\
#        AND dr3.pm is not null\
#        AND p.classprob_dsc_allosmod_galaxy > 0.999\
#        AND dr3.phot_g_mean_mag > 14.5\
#        ORDER BY dr3.random_index"

##query_galaxy = "SELECT TOP 15000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.astrometric_chi2_al, astrometric_n_good_obs_al,\
#                dr3.phot_g_n_obs, dr3.phot_g_mean_flux_over_error, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
#                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
#                p.classprob_dsc_allosmod_star AS star\
#        FROM gaiadr3.gaia_source as dr3\
#        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
#        WHERE dr3.parallax is not null\
#        AND dr3.pm is not null\
#        AND p.classprob_dsc_allosmod_galaxy > 0.999\
#        AND dr3.phot_g_mean_mag > 14.5\
#        ORDER BY dr3.random_index"

query_galaxy = "SELECT TOP 90000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
                dr3.astrometric_chi2_al, dr3.astrometric_n_good_obs_al, dr3.phot_g_n_obs, dr3.phot_g_mean_flux_over_error,\
                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
                p.classprob_dsc_allosmod_star AS star\
        FROM gaiadr3.gaia_source as dr3\
        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
        WHERE dr3.parallax is not null\
        AND dr3.pm is not null\
        AND dr3.phot_g_mean_mag is not null\
        AND dr3.bp_g is not null\
        AND dr3.g_rp is not null\
        AND dr3.astrometric_chi2_al is not null\
        AND dr3.astrometric_n_good_obs_al is not null\
        AND dr3.phot_g_n_obs is not null\
        AND dr3.phot_g_mean_flux_over_error is not null\
        AND p.classprob_dsc_allosmod_galaxy > 0.999\
        AND dr3.phot_g_mean_mag > 14.5\
        AND 0.3 + 1.1*dr3.bp_g - 0.29*POWER((dr3.bp_g),2) < dr3.g_rp\
        ORDER BY dr3.random_index"

query_star = "SELECT TOP 90000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
                dr3.astrometric_chi2_al, dr3.astrometric_n_good_obs_al, dr3.phot_g_n_obs, dr3.phot_g_mean_flux_over_error,\
                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
                p.classprob_dsc_allosmod_star AS star\
        FROM gaiadr3.gaia_source as dr3\
        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
        WHERE dr3.parallax is not null\
        AND dr3.pm is not null\
        AND dr3.phot_g_mean_mag is not null\
        AND dr3.bp_g is not null\
        AND dr3.g_rp is not null\
        AND dr3.astrometric_chi2_al is not null\
        AND dr3.astrometric_n_good_obs_al is not null\
        AND dr3.phot_g_n_obs is not null\
        AND dr3.phot_g_mean_flux_over_error is not null\
        AND p.classprob_dsc_allosmod_star > 0.999\
        AND dr3.phot_g_mean_mag > 14.5\
        AND 0.3 + 1.1*dr3.bp_g - 0.29*POWER((dr3.bp_g),2) < dr3.g_rp\
        ORDER BY dr3.random_index"
##query_star = "SELECT TOP 15000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.astrometric_chi2_al, astrometric_n_good_obs_al,\
#                dr3.phot_g_n_obs, dr3.phot_g_mean_flux_over_error, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
#                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
#                p.classprob_dsc_allosmod_star AS star\
#        FROM gaiadr3.gaia_source as dr3\
#        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
#        WHERE dr3.parallax is not null\
#        AND dr3.pm is not null\
#        AND p.classprob_dsc_allosmod_star > 0.999\
#        AND dr3.phot_g_mean_mag > 14.5\
#        ORDER BY dr3.random_index"
# query = "SELECT dr3.source_id, p.classlabel_espels\
#         FROM gaiadr3.gaia_source AS dr3\
#         LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
#         WHERE p.classlabel_espels IS NOT NULL\
#         AND random_index between 0 and 100000000"

query_quasar =  "SELECT TOP 90000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
                dr3.astrometric_chi2_al, dr3.astrometric_n_good_obs_al, dr3.phot_g_n_obs, dr3.phot_g_mean_flux_over_error,\
                p.classprob_dsc_allosmod_quasar AS quasar, p.classprob_dsc_allosmod_galaxy AS galaxy,\
                p.classprob_dsc_allosmod_star AS star\
        FROM gaiadr3.gaia_source as dr3\
        LEFT JOIN gaiadr3.astrophysical_parameters AS p USING (source_id)\
        WHERE dr3.parallax is not null\
        AND dr3.pm is not null\
        AND dr3.phot_g_mean_mag is not null\
        AND dr3.bp_g is not null\
        AND dr3.g_rp is not null\
        AND dr3.astrometric_chi2_al is not null\
        AND dr3.astrometric_n_good_obs_al is not null\
        AND dr3.phot_g_n_obs is not null\
        AND dr3.phot_g_mean_flux_over_error is not null\
        AND p.classprob_dsc_allosmod_quasar > 0.999\
        AND dr3.phot_g_mean_mag > 14.5\
        AND 0.3 + 1.1*dr3.bp_g - 0.29*POWER((dr3.bp_g),2) < dr3.g_rp\
        ORDER BY dr3.random_index"

jobq = Gaia.launch_job_async(query_quasar)
jobg = Gaia.launch_job_async(query_galaxy)
jobs = Gaia.launch_job_async(query_star)

gtable = jobg.get_results()
stable = jobs.get_results()
qtable = jobq.get_results()
gtable
# Out:
#   Cell In[187], line 24
#     query_galaxy = "SELECT TOP 90000 dr3.source_id, dr3.random_index, dr3.ra, dr3.dec, dr3.b, dr3.parallax, dr3.pm, dr3.phot_g_mean_mag, dr3.bp_g, dr3.g_rp,\
#                    ^
# SyntaxError: unterminated string literal (detected at line 41)

# %%
datag = gtable
datas = stable
dataq = qtable

# %%
datag = datag.to_pandas()
datas = datas.to_pandas()
dataq = dataq.to_pandas()

# %%
import matplotlib.pyplot as plt
import pandas as pd


plt.scatter(datag['ra'], datag['dec'], s = 0.05, c = 'indigo')
plt.scatter(dataq['ra'], dataq['dec'], s = 0.05, c = 'violet')
plt.scatter(datas['ra'], datas['dec'], s = 0.05, c = 'gold')

# %%
datag['classification'] = datag[['quasar', 'galaxy', 'star']].idxmax(axis=1, skipna = True)
datas['classification'] = datas[['quasar', 'galaxy', 'star']].idxmax(axis=1, skipna = True)
dataq['classification'] = dataq[['quasar', 'galaxy', 'star']].idxmax(axis=1, skipna = True)

# %%
combined = pd.concat([datag, datas, dataq], ignore_index=True)
combined
# Out:
#                   source_id  random_index          ra        dec          b  \
# 0       1265515347877933440         10075  222.274888  22.198161  62.881857
# 1       5361196917262946432         15072  162.225588 -49.752394   8.437576
# 2       1232222032709253760         21887  214.149981  16.513552  67.616105
# 3       2036211254522971136         31435  288.127524  26.288061   7.393590
# 4       1508859364417098624         48386  210.664719  46.206344  66.287072
# ...                     ...           ...         ...        ...        ...
# 299995  5461622014371289216     283337760  155.824205 -29.697786  23.030666
# 299996  1121121841625951360     283339892  140.944456  73.375024  36.440425
# 299997  1679026003043373056     283340132  192.934222  66.151277  50.976945
# 299998   665083627182479360     283345507  131.223566  22.126522  34.292558
# 299999  3642866362818704000     283348206  216.773812  -4.371739  50.937534
#
#         parallax        pm  astrometric_chi2_al  astrometric_n_good_obs_al  \
# 0      -0.336690  0.717317          2874.529297                        557
# 1      -0.036707  5.728018           163.854965                        119
# 2       1.771744  2.912953           500.056610                        211
# 3      -0.281428  5.787940           358.140594                        344
# 4      -0.299802  0.610444          1701.720337                        393
# ...          ...       ...                  ...                        ...
# 299995  0.120797  1.193289           210.935898                        221
# 299996  0.068023  0.226807           404.327271                        448
# 299997 -0.414755  0.360979           305.734497                        294
# 299998 -0.759137  0.772558           458.713104                        396
# 299999 -0.031845  1.119564           193.238770                        178
#
#         phot_g_n_obs  phot_g_mean_flux_over_error  phot_g_mean_mag      bp_g  \
# 0                540                   134.341766        17.933859 -2.318183
# 1                103                    77.483009        19.842285 -2.758350
# 2                261                    91.175278        20.476004 -1.030676
# 3                337                   204.914261        20.342360       NaN
# 4                523                   102.935295        18.904287 -1.698452
# ...              ...                          ...              ...       ...
# 299995           237                   105.350121        20.239737 -0.043226
# 299996           487                   281.857819        19.225611  0.273825
# 299997           331                   165.733673        20.004629  0.239792
# 299998           399                   170.532761        20.198053  0.080513
# 299999           195                   165.591522        19.767195  0.203079
#
#             g_rp        quasar        galaxy          star classification
# 0       3.621396  2.242062e-11  1.000000e+00  1.096192e-10         galaxy
# 1       4.355935  9.393035e-12  9.991883e-01  8.117138e-04         galaxy
# 2       2.346783  2.140544e-05  9.999388e-01  3.978026e-05         galaxy
# 3            NaN  3.905006e-32  9.999024e-01  9.763462e-05         galaxy
# 4       2.988806  6.760223e-08  9.999999e-01  2.498582e-08         galaxy
# ...          ...           ...           ...           ...            ...
# 299995  0.480465  9.996330e-01  4.737906e-06  3.623170e-04         quasar
# 299996  0.425482  9.999996e-01  3.789731e-07  2.446934e-08         quasar
# 299997  0.559464  9.999851e-01  1.446926e-05  4.320148e-07         quasar
# 299998  0.341600  9.993750e-01  2.436425e-06  6.225743e-04         quasar
# 299999  0.400742  9.995405e-01  7.995563e-06  4.514887e-04         quasar
#
# [300000 rows x 18 columns]

# %%
combined['classification'].value_counts()
# Out:
# classification
# galaxy    100000
# star      100000
# quasar    100000
# Name: count, dtype: int64

# %%
import numpy as np
combined['uwe'] = np.sqrt(combined['astrometric_chi2_al']/(combined['astrometric_n_good_obs_al']-5))
combined['relvarg'] = np.sqrt(combined['phot_g_mean_flux_over_error'])/combined['phot_g_mean_mag']
combined['sinb']  = np.sin(combined['b']* np.pi / 180)
combined
# Out:
#                   source_id  random_index          ra        dec          b  \
# 0       1265515347877933440         10075  222.274888  22.198161  62.881857
# 1       5361196917262946432         15072  162.225588 -49.752394   8.437576
# 2       1232222032709253760         21887  214.149981  16.513552  67.616105
# 3       2036211254522971136         31435  288.127524  26.288061   7.393590
# 4       1508859364417098624         48386  210.664719  46.206344  66.287072
# ...                     ...           ...         ...        ...        ...
# 299995  5461622014371289216     283337760  155.824205 -29.697786  23.030666
# 299996  1121121841625951360     283339892  140.944456  73.375024  36.440425
# 299997  1679026003043373056     283340132  192.934222  66.151277  50.976945
# 299998   665083627182479360     283345507  131.223566  22.126522  34.292558
# 299999  3642866362818704000     283348206  216.773812  -4.371739  50.937534
#
#         parallax        pm  astrometric_chi2_al  astrometric_n_good_obs_al  \
# 0      -0.336690  0.717317          2874.529297                        557
# 1      -0.036707  5.728018           163.854965                        119
# 2       1.771744  2.912953           500.056610                        211
# 3      -0.281428  5.787940           358.140594                        344
# 4      -0.299802  0.610444          1701.720337                        393
# ...          ...       ...                  ...                        ...
# 299995  0.120797  1.193289           210.935898                        221
# 299996  0.068023  0.226807           404.327271                        448
# 299997 -0.414755  0.360979           305.734497                        294
# 299998 -0.759137  0.772558           458.713104                        396
# 299999 -0.031845  1.119564           193.238770                        178
#
#         phot_g_n_obs  ...  phot_g_mean_mag      bp_g      g_rp        quasar  \
# 0                540  ...        17.933859 -2.318183  3.621396  2.242062e-11
# 1                103  ...        19.842285 -2.758350  4.355935  9.393035e-12
# 2                261  ...        20.476004 -1.030676  2.346783  2.140544e-05
# 3                337  ...        20.342360       NaN       NaN  3.905006e-32
# 4                523  ...        18.904287 -1.698452  2.988806  6.760223e-08
# ...              ...  ...              ...       ...       ...           ...
# 299995           237  ...        20.239737 -0.043226  0.480465  9.996330e-01
# 299996           487  ...        19.225611  0.273825  0.425482  9.999996e-01
# 299997           331  ...        20.004629  0.239792  0.559464  9.999851e-01
# 299998           399  ...        20.198053  0.080513  0.341600  9.993750e-01
# 299999           195  ...        19.767195  0.203079  0.400742  9.995405e-01
#
#               galaxy          star  classification       uwe   relvarg  \
# 0       1.000000e+00  1.096192e-10          galaxy  2.281991  0.646296
# 1       9.991883e-01  8.117138e-04          galaxy  1.198885  0.443620
# 2       9.999388e-01  3.978026e-05          galaxy  1.558031  0.466330
# 3       9.999024e-01  9.763462e-05          galaxy  1.027843  0.703695
# 4       9.999999e-01  2.498582e-08          galaxy  2.094249  0.536688
# ...              ...           ...             ...       ...       ...
# 299995  4.737906e-06  3.623170e-04          quasar  0.988208  0.507122
# 299996  3.789731e-07  2.446934e-08          quasar  0.955355  0.873243
# 299997  1.446926e-05  4.320148e-07          quasar  1.028545  0.643539
# 299998  2.436425e-06  6.225743e-04          quasar  1.083134  0.646538
# 299999  7.995563e-06  4.514887e-04          quasar  1.056876  0.650990
#
#             sinb
# 0       0.890069
# 1       0.146732
# 2       0.924653
# 3       0.128685
# 4       0.915572
# ...          ...
# 299995  0.391224
# 299996  0.593987
# 299997  0.776893
# 299998  0.563419
# 299999  0.776459
#
# [300000 rows x 21 columns]

# %%
from astropy.table import Table

table = Table.from_pandas(combined)

# %%
from astropy.io import fits

table.write("TESTData_kstars_kgalaxies_kquasars.fits", format="fits", overwrite=True)

# %%
loaded = Table.read("Data_100kstars_100kgalaxies_100kquasars.fits", format="fits")

# %%
print(loaded.colnames)
# Out:
# ['source_id', 'random_index', 'ra', 'dec', 'b', 'parallax', 'pm', 'astrometric_chi2_al', 'astrometric_n_good_obs_al', 'phot_g_n_obs', 'phot_g_mean_flux_over_error', 'phot_g_mean_mag', 'bp_g', 'g_rp', 'quasar', 'galaxy', 'star', 'classification', 'uwe', 'relvarg', 'sinb']

# %%
plt.hist(np.array(combined['sinb']))
# Out:
# (array([24830., 20177., 13234., 11481., 46595., 42355., 20338., 30693.,
#         38848., 51449.]),
#  array([-9.99999934e-01, -8.00000338e-01, -6.00000742e-01, -4.00001147e-01,
#         -2.00001551e-01, -1.95568473e-06,  1.99997640e-01,  3.99997235e-01,
#          5.99996831e-01,  7.99996427e-01,  9.99996022e-01]),
#  <BarContainer object of 10 artists>)
